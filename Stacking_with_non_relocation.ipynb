# %%
import pandas as pd
import os
import glob
import numpy as np

# %% [markdown]
# new_value 생성 : 우선 순위가 높은 컨테이너에 대해 높은 new_value값 할당

# %%
def calculate_score(weights, priorities):
    w_max = 24
    if isinstance(weights, (list, np.ndarray)):
        scores = []
        for weight, p in zip(weights, priorities):
            if p != 0:
                score = w_max + p
            else:
                score = weight
            scores.append((score))
        return scores
    else:
        if priorities != 0:
            return int(w_max + priorities)
        else:
            return (weights)

# %%
# isinstance : 주어진 객체가 특정 클래스나 클래스의 튜플 중 하나에 속하는지 여부 
# isinstance(object, classinfo)  which is object : 확인할 객체, classinfo : 하나의 클래스나 클래스의 튜플
# object(객체)가 classinfo에 속하면 true 반환, 아니면 false 반환

# %% [markdown]
# output 데이터프레임 생성

# %%
def create_dataframe_from_stacks(container_info):
    data = []
    for info in container_info.values():
        data.append({
            'idx': info['idx'],
            'weight': info['weight'],
            'new_value': info['new_value'],
            'relocation': info['relocations'],
            'loc_x': info['loc_x'],
            'loc_y': 0,
            'loc_z': info['loc_z'],
            'size(ft)': 20
        })
    return pd.DataFrame(data)

# %% [markdown]
# input csv 파일 로드하여 초기 상태와 새로운 컨테이너 데이터를 로드

# %%
def load_and_transform_data(initial_state_path, container_path):
    initial_state_df = pd.read_csv(initial_state_path)
    container_df = pd.read_csv(container_path)

    new_weight = container_df['weight'].tolist()
    priority = container_df['priority'].tolist()
    new_weights = calculate_score(new_weight, priority) #new_value 값으로 list 얻음

    container_info = {}
    for _, row in initial_state_df.iterrows():
        idx = int(row['idx'])
        weight = row['weight']
        loc_x = int(row['loc_x'])
        loc_y = 0
        loc_z = int(row['loc_z'])
        new_value = calculate_score(weight, row['priority']) #new_value 값

        container_info[idx] = {
            'idx': idx,
            'weight': weight,
            'new_value': new_value,
            'relocations': 0,
            'loc_x': loc_x,
            'loc_y': loc_y,
            'loc_z': loc_z
        }

    for _, row in container_df.iterrows():
        idx = int(row['idx'])
        weight = row['weight']
        new_value = calculate_score(weight, row['priority'])
        container_info[idx] = {
            'idx': idx,
            'weight': weight,
            'new_value': new_value,
            'relocations': 0,
            'loc_x': None,
            'loc_y': None,
            'loc_z': None
        }

    stacks = [[None] * 5 for _ in range(6)] # stacks 생성

    for _, row in initial_state_df.iterrows():
        x = int(row['loc_x']) - 1
        z = int(row['loc_z'])
        idx = int(row['idx'])
        stacks[x][z] = container_info[idx]['new_value']

    return stacks, new_weights, container_info

# %%
# .tolist() :  데이터 프레임이나 시리즈의 데이터를 리스트(list)로 변환하는데 사용
# 즉, pandas 객체를 파이썬의 기본 리스트 형태로 쉽게 변환

#.iterrows() : pandas 라이브러리에서 데이터프레임의 각 행(하지만 여기 데이터에서는 열임)을 반복하는데 사용되는 메서드
# 데이터 프레임의 각 행을 (index, Series)형태의 튜플로 반환 
# index는 행의 인덱스
# Series는 해당 행의 데이터를 포함하는 pandas 시리즈 객체

# %% [markdown]
# 이상적인 형상을 위한 무게레벨 설정(무게 레벨은 1~9)

# %%
def calculate_weight_levels(weights):
    levels = []
    interval = 8
    w_min = min(weights)
    w_max = max(weights)
    
    for w_c in weights:
        level = ((w_c - w_min) / (w_max - w_min) * interval) + 1
        levels.append(int(level))  
    
    return levels

# %% [markdown]
# 이상적인 형상의 이상적인 좌표 설정

# %%
def get_ideal_positions(new_weights, stacks):
    weight_levels = calculate_weight_levels(new_weights) #무게레벨 계산

    positions = [
        (0,0), (0,1), (1,0), (0,2), (1, 1), (2,0), (0,3), (1,2), (2,1), (3,0),
        (0,4), (1,3), (2,2), (3,1), (4,0), (1,4), (2,3), (3,2), (4,1), (5,0),
        (2,4), (3,3), (4,2), (5,1), (3,4), (4,3), (5,2), (4,4), (5,3), (5,4)
    ]

    occupied_stacks = {i for i, stack in enumerate(stacks) if any(tier is not None for tier in stack)}
    available_positions = [pos for pos in positions if pos[0] not in occupied_stacks]

    weight_positions = {level: [] for level in set(weight_levels)}

    pos_index = 0
    for level in sorted(set(weight_levels)):
        positions_needed = weight_levels.count(level)
        for _ in range(positions_needed):
            if pos_index < len(available_positions):
                weight_positions[level].append(available_positions[pos_index])
                pos_index += 1
            else:
                break

    weight_to_positions = {weight: weight_positions[level] for weight, level in zip(new_weights, weight_levels)}

    return weight_to_positions, weight_positions

# %%
# any : 반복 가능한 객체가 하나라도 참인 경우에 참을 반환

# %% [markdown]
# 이상적인 좌표에 스택킹 가능하면 이상적인 좌표에 우선적으로 스택킹

# %%
def place_container(stacks, weight, positions, container_info):
    placed = False
    for position in positions:
        stack_num, tier_num = position
        if all(stacks[stack_num][i] is not None for i in range(tier_num)) and stacks[stack_num][tier_num] is None:
            stacks[stack_num][tier_num] = weight
            for idx, info in container_info.items():
                if info['idx'] == idx and info['new_value'] == weight and info['loc_x'] is None:
                    info['loc_x'] = stack_num + 1
                    info['loc_z'] = tier_num
                    print(f"Container index: {idx}, new_value: {info['new_value']}, loc_x: {info['loc_x']}, loc_z: {info['loc_z']}")
                    placed = True
                    break  # 내부 for 루프를 종료
            if placed:
                break  # 외부 for 루프를 종료
    return placed

# %%
# .items() : 사전의 모든 키-값 쌍을 (키, 값) 형태의 튜플로 반환
# 'idx'값을 info의 키로 씀

# %% [markdown]
# 무게 차이 고려한 stacking

# %%
def final_relocation_single(stacks, weight, container_info):
    best_stack = -1
    best_difference = float('inf')

    for stack_num in range(len(stacks)):
        for tier_num in range(len(stacks[stack_num])):
            if stacks[stack_num][tier_num] is None:
                if tier_num == 0 or stacks[stack_num][tier_num - 1] is not None:
                    if tier_num > 0:
                        top_weight = stacks[stack_num][tier_num - 1]
                        difference = weight - top_weight
                    else:
                        difference = weight

                    if difference >= 0 and difference < best_difference:
                        best_stack = stack_num
                        best_difference = difference

    if best_stack == -1:
        best_stack = 0
        best_difference = float('inf')
        for stack_num in range(len(stacks)):
            for tier_num in range(len(stacks[stack_num])):
                if stacks[stack_num][tier_num] is None:
                    if tier_num == 0 or stacks[stack_num][tier_num - 1] is not None:
                        if tier_num > 0:
                            top_weight = stacks[stack_num][tier_num - 1]
                            difference = weight - top_weight
                        else:
                            difference = weight

                        if abs(difference) < abs(best_difference):
                            best_stack = stack_num
                            best_difference = difference

    for tier_num in range(len(stacks[best_stack])):
        if stacks[best_stack][tier_num] is None:
            stacks[best_stack][tier_num] = weight
            for idx, info in container_info.items():
                if info['idx'] == idx and info['new_value'] == weight and info['loc_x'] is None:
                    info['loc_x'] = best_stack + 1
                    info['loc_z'] = tier_num
                    print(f"Container index: {idx}, new_value: {info['new_value']}, loc_x: {info['loc_x']}, loc_z: {info['loc_z']}")
                    break
            print(f"Placed weight {weight} in Stack {best_stack + 1}, Tier {tier_num + 1}")
            break

# %% [markdown]
# 컨테이너 시각화

# %%
def print_stacks(stacks):
    for i, stack in enumerate(stacks):
        print(f"Stack {i+1}: {stack}")

def print_weight_positions(weight_positions):
    for weight, positions in weight_positions.items():
        print(f"Weight {weight}: {positions}")

def print_level_positions(level_positions):
    for level, positions in level_positions.items():
        print(f"Level {level}: {positions}")

# %% [markdown]
# 기존 컨테이너 재정렬

# %%
def relocate_top_containers(stacks, container_info):
    relocation_count = 0

    while True:
        top_weights = []
        for i, stack in enumerate(stacks):
            for tier in range(len(stack) - 1, -1, -1):
                if stack[tier] is not None:
                    top_weights.append((stack[tier], i, tier))
                    break

        top_weights.sort(key=lambda x: (x[0], x[2])) # 무게 같으면 tier 낮은 거 먼저 탐색

        relocated = False
        for weight, stack_num, tier in top_weights:
            best_stack = stack_num
            best_difference = float('inf')

            for target_stack_num in range(len(stacks)):
                if target_stack_num != stack_num:
                    for target_tier in range(len(stacks[target_stack_num])):
                        if stacks[target_stack_num][target_tier] is None:
                            if target_tier == 0 or stacks[target_stack_num][target_tier - 1] is not None:
                                if target_tier > 0:
                                    top_weight = stacks[target_stack_num][target_tier - 1]
                                    difference = weight - top_weight
                                else:
                                    difference = weight

                                if 0 <= difference < best_difference and difference < abs((weight - (stacks[stack_num][tier - 1] if tier > 0 else 0))):
                                    best_stack = target_stack_num
                                    best_difference = difference

                            break

            if best_stack != stack_num:
                for target_tier in range(len(stacks[best_stack])):
                    if stacks[best_stack][target_tier] is None:
                        stacks[best_stack][target_tier] = weight
                        stacks[stack_num][tier] = None
                        relocation_count += 1

                        print(f"Relocated weight {weight} from Stack {stack_num + 1} to Stack {best_stack + 1}")

                        # Update container_info for the relocated container
                        for info in container_info.values():
                            if info['new_value'] == weight and info['loc_x'] == stack_num + 1 and info['loc_z'] == tier:
                                info['relocations'] += 1
                                info['loc_x'] = best_stack + 1
                                info['loc_z'] = target_tier
                                break

                        relocated = True
                        break

            if relocated:
                break

        if not relocated:
            break

    print(f"Total relocations: {relocation_count}")
    return relocation_count

# %% [markdown]
# 비어 있는 stack 확인

# %%
def get_empty_stacks(stacks):
    empty_stacks = []
    for stack_num, stack in enumerate(stacks):
        if all(tier is None for tier in stack):
            empty_stacks.append(stack_num)
    return empty_stacks

# %% [markdown]
# 컨테이너 배치 과정 총 로직

# %%
def container_placement_process(initial_stacks, new_weights, original_weights_mapping, container_info):
    print("Initial stacks before any new weights are added:")
    print_stacks(initial_stacks)
    print("-------------------------------------------------------------------")

    total_relocations = relocate_top_containers(initial_stacks, container_info)
    print("Stacks after relocating initial stacks:")
    print_stacks(initial_stacks)
    print("-------------------------------------------------------------------")

    empty_stacks = get_empty_stacks(initial_stacks)
    print(f"Empty stacks after relocation: {empty_stacks}")

    weight_to_positions, level_positions = get_ideal_positions(new_weights, initial_stacks)

    print("Ideal candidate location for new weights")
    print_level_positions(level_positions)
    print("-------------------------------------------------------------------")
    print_weight_positions(weight_to_positions)
    print("-------------------------------------------------------------------")

    for i, new_weight in enumerate(new_weights):
        actual_weight = original_weights_mapping[new_weight]
        print(f"\nStep {i + 1}: Placing new value {new_weight} (actual weight: {actual_weight})")

        ideal_positions = weight_to_positions[new_weight]
        if place_container(initial_stacks, new_weight, ideal_positions, container_info):
            print(f"Placed new value {new_weight} (actual weight: {actual_weight}) in ideal position")
        else:
            final_relocation_single(initial_stacks, new_weight, container_info)

        print_stacks(initial_stacks)

    return total_relocations

# %% [markdown]
# input 데이터를 통해 컨테이너 stacking 후 output데이터로 저장

# %%
def main():
    input_dir = 'C:\\Users\\user\\OneDrive\\바탕 화면\\Container\\input\\'
    output_dir = 'C:\\Users\\user\\OneDrive\\바탕 화면\\Container\\output\\'

    initial_files = sorted(glob.glob(os.path.join(input_dir, 'Initial_state_ex*.csv')))
    container_files = sorted(glob.glob(os.path.join(input_dir, 'Container_ex*.csv')))

    if len(initial_files) != len(container_files):
        print("Error: Mismatched number of initial state and container files.")
        return

    for i in range(len(initial_files)):
        initial_state_path = initial_files[i]
        container_path = container_files[i]
        output_file_name = f'Non_relocation_ex{i + 1}.csv'
        output_file_path = os.path.join(output_dir, output_file_name)

        initial_stacks, new_weights, container_info = load_and_transform_data(initial_state_path, container_path)

        total_relocations = container_placement_process(initial_stacks, new_weights, {new_weight: weight for new_weight, weight in zip(new_weights, pd.read_csv(container_path)['weight'].tolist())}, container_info)
        output = create_dataframe_from_stacks(container_info)

        print(output)
        output.to_csv(output_file_path, index=False)

# %%
# os.path.join : 이 함수는 여러 경로 요소를 하나의 경로로 결합.
# 예로, os.path.koin('folder', 'file.txt')이라면, 'folder\file.txt로 반환

# 'Initial_state_ex*'.csv : Initial_state_ex로 시작하고, 그 뒤에 어떤 문자열이 올 수 있으며, .csv로 끝나는  모든 파일을 찾음

#glob.glob : glob 모듈의 glob 함수는 주어진 패턴에 맞는 모든 파일 경로를 리스트로 반환함
# 현재, 여기에선 .csv 파일이 주어진 패턴

# {new_weight: weight for new_weight, weight in zip(new_weights, pd.read_csv(container_path)['weight'].tolist())}
# 이 코드는 pd.read_csv(container_path)['weight'].tolist() => 실제 무게
# new_weights(new_value값과 동일)를 실제 무게와 대응시켜줌
# orginal_weights_mapping이란 이름으로 'container_placement_process' 들어감

# %% [markdown]
# 실행

# %%
main()
# Out:
# Initial stacks before any new weights are added:
# Stack 1: [2.96, None, None, None, None]
# Stack 2: [3.5, 43, 6.0, None, None]
# Stack 3: [42, None, None, None, None]
# Stack 4: [None, None, None, None, None]
# Stack 5: [None, None, None, None, None]
# Stack 6: [None, None, None, None, None]
# -------------------------------------------------------------------
# Relocated weight 6.0 from Stack 2 to Stack 1
# Relocated weight 42 from Stack 3 to Stack 1
# Relocated weight 43 from Stack 2 to Stack 1
# Total relocations: 3
# Stacks after relocating initial stacks:
# Stack 1: [2.96, 6.0, 42, 43, None]
# Stack 2: [3.5, None, None, None, None]
# Stack 3: [None, None, None, None, None]
# Stack 4: [None, None, None, None, None]
# Stack 5: [None, None, None, None, None]
# Stack 6: [None, None, None, None, None]
# -------------------------------------------------------------------
# Empty stacks after relocation: [2, 3, 4, 5]
# Ideal candidate location for new weights
# Level 1: [(2, 0), (2, 1), (3, 0), (2, 2), (3, 1), (4, 0), (2, 3), (3, 2)]
# Level 2: [(4, 1), (5, 0), (2, 4)]
# Level 6: [(3, 3)]
# Level 7: [(4, 2), (5, 1), (3, 4)]
# Level 8: [(4, 3)]
# Level 9: [(5, 2)]
# -------------------------------------------------------------------
# Weight 2.96: [(2, 0), (2, 1), (3, 0), (2, 2), (3, 1), (4, 0), (2, 3), (3, 2)]
# Weight 3.5: [(2, 0), (2, 1), (3, 0), (2, 2), (3, 1), (4, 0), (2, 3), (3, 2)]
# Weight 4.4: [(2, 0), (2, 1), (3, 0), (2, 2), (3, 1), (4, 0), (2, 3), (3, 2)]
# Weight 6.6: [(4, 1), (5, 0), (2, 4)]
# Weight 3.8: [(2, 0), (2, 1), (3, 0), (2, 2), (3, 1), (4, 0), (2, 3), (3, 2)]
# Weight 5.0: [(4, 1), (5, 0), (2, 4)]
# Weight 6.0: [(4, 1), (5, 0), (2, 4)]
# Weight 20.0: [(4, 2), (5, 1), (3, 4)]
# Weight 19.5: [(4, 2), (5, 1), (3, 4)]
# Weight 17.4: [(3, 3)]
# Weight 20.37: [(4, 2), (5, 1), (3, 4)]
# Weight 24.0: [(5, 2)]
# Weight 2.0: [(2, 0), (2, 1), (3, 0), (2, 2), (3, 1), (4, 0), (2, 3), (3, 2)]
# Weight 3.0: [(2, 0), (2, 1), (3, 0), (2, 2), (3, 1), (4, 0), (2, 3), (3, 2)]
# Weight 4.0: [(2, 0), (2, 1), (3, 0), (2, 2), (3, 1), (4, 0), (2, 3), (3, 2)]
# Weight 22.0: [(4, 3)]
# -------------------------------------------------------------------
#
# Step 1: Placing new value 2.96 (actual weight: 2.96)
# Container index: 100, new_value: 2.96, loc_x: 3, loc_z: 0
# Placed new value 2.96 (actual weight: 2.96) in ideal position
# Stack 1: [2.96, 6.0, 42, 43, None]
# Stack 2: [3.5, None, None, None, None]
# Stack 3: [2.96, None, None, None, None]
# Stack 4: [None, None, None, None, None]
# Stack 5: [None, None, None, None, None]
# Stack 6: [None, None, None, None, None]
#
# Step 2: Placing new value 3.5 (actual weight: 3.5)
# Container index: 6, new_value: 3.5, loc_x: 3, loc_z: 1
# Placed new value 3.5 (actual weight: 3.5) in ideal position
# Stack 1: [2.96, 6.0, 42, 43, None]
# Stack 2: [3.5, None, None, None, None]
# Stack 3: [2.96, 3.5, None, None, None]
# Stack 4: [None, None, None, None, None]
# Stack 5: [None, None, None, None, None]
# Stack 6: [None, None, None, None, None]
#
# Step 3: Placing new value 4.4 (actual weight: 4.4)
# Container index: 7, new_value: 4.4, loc_x: 4, loc_z: 0
# Placed new value 4.4 (actual weight: 4.4) in ideal position
# Stack 1: [2.96, 6.0, 42, 43, None]
# Stack 2: [3.5, None, None, None, None]
# Stack 3: [2.96, 3.5, None, None, None]
# Stack 4: [4.4, None, None, None, None]
# Stack 5: [None, None, None, None, None]
# Stack 6: [None, None, None, None, None]
#
# Step 4: Placing new value 6.6 (actual weight: 6.6)
# Container index: 8, new_value: 6.6, loc_x: 6, loc_z: 0
# Placed new value 6.6 (actual weight: 6.6) in ideal position
# Stack 1: [2.96, 6.0, 42, 43, None]
# Stack 2: [3.5, None, None, None, None]
# Stack 3: [2.96, 3.5, None, None, None]
# Stack 4: [4.4, None, None, None, None]
# Stack 5: [None, None, None, None, None]
# Stack 6: [6.6, None, None, None, None]
#
# Step 5: Placing new value 3.8 (actual weight: 3.8)
# Container index: 9, new_value: 3.8, loc_x: 3, loc_z: 2
# Placed new value 3.8 (actual weight: 3.8) in ideal position
# Stack 1: [2.96, 6.0, 42, 43, None]
# Stack 2: [3.5, None, None, None, None]
# Stack 3: [2.96, 3.5, 3.8, None, None]
# Stack 4: [4.4, None, None, None, None]
# Stack 5: [None, None, None, None, None]
# Stack 6: [6.6, None, None, None, None]
#
# Step 6: Placing new value 5.0 (actual weight: 5.0)
# Container index: 10, new_value: 5.0, loc_x: 4, loc_z: 1
# Placed weight 5.0 in Stack 4, Tier 2
# Stack 1: [2.96, 6.0, 42, 43, None]
# Stack 2: [3.5, None, None, None, None]
# Stack 3: [2.96, 3.5, 3.8, None, None]
# Stack 4: [4.4, 5.0, None, None, None]
# Stack 5: [None, None, None, None, None]
# Stack 6: [6.6, None, None, None, None]
#
# Step 7: Placing new value 6.0 (actual weight: 6.0)
# Container index: 11, new_value: 6.0, loc_x: 4, loc_z: 2
# Placed weight 6.0 in Stack 4, Tier 3
# Stack 1: [2.96, 6.0, 42, 43, None]
# Stack 2: [3.5, None, None, None, None]
# Stack 3: [2.96, 3.5, 3.8, None, None]
# Stack 4: [4.4, 5.0, 6.0, None, None]
# Stack 5: [None, None, None, None, None]
# Stack 6: [6.6, None, None, None, None]
#
# Step 8: Placing new value 20.0 (actual weight: 20.0)
# Container index: 12, new_value: 20.0, loc_x: 6, loc_z: 1
# Placed new value 20.0 (actual weight: 20.0) in ideal position
# Stack 1: [2.96, 6.0, 42, 43, None]
# Stack 2: [3.5, None, None, None, None]
# Stack 3: [2.96, 3.5, 3.8, None, None]
# Stack 4: [4.4, 5.0, 6.0, None, None]
# Stack 5: [None, None, None, None, None]
# Stack 6: [6.6, 20.0, None, None, None]
#
# Step 9: Placing new value 19.5 (actual weight: 19.5)
# Container index: 13, new_value: 19.5, loc_x: 4, loc_z: 3
# Placed weight 19.5 in Stack 4, Tier 4
# Stack 1: [2.96, 6.0, 42, 43, None]
# Stack 2: [3.5, None, None, None, None]
# Stack 3: [2.96, 3.5, 3.8, None, None]
# Stack 4: [4.4, 5.0, 6.0, 19.5, None]
# Stack 5: [None, None, None, None, None]
# Stack 6: [6.6, 20.0, None, None, None]
#
# Step 10: Placing new value 17.4 (actual weight: 17.4)
# Container index: 14, new_value: 17.4, loc_x: 3, loc_z: 3
# Placed weight 17.4 in Stack 3, Tier 4
# Stack 1: [2.96, 6.0, 42, 43, None]
# Stack 2: [3.5, None, None, None, None]
# Stack 3: [2.96, 3.5, 3.8, 17.4, None]
# Stack 4: [4.4, 5.0, 6.0, 19.5, None]
# Stack 5: [None, None, None, None, None]
# Stack 6: [6.6, 20.0, None, None, None]
#
# Step 11: Placing new value 20.37 (actual weight: 20.37)
# Container index: 15, new_value: 20.37, loc_x: 4, loc_z: 4
# Placed new value 20.37 (actual weight: 20.37) in ideal position
# Stack 1: [2.96, 6.0, 42, 43, None]
# Stack 2: [3.5, None, None, None, None]
# Stack 3: [2.96, 3.5, 3.8, 17.4, None]
# Stack 4: [4.4, 5.0, 6.0, 19.5, 20.37]
# Stack 5: [None, None, None, None, None]
# Stack 6: [6.6, 20.0, None, None, None]
#
# Step 12: Placing new value 24.0 (actual weight: 24.0)
# Container index: 16, new_value: 24.0, loc_x: 6, loc_z: 2
# Placed new value 24.0 (actual weight: 24.0) in ideal position
# Stack 1: [2.96, 6.0, 42, 43, None]
# Stack 2: [3.5, None, None, None, None]
# Stack 3: [2.96, 3.5, 3.8, 17.4, None]
# Stack 4: [4.4, 5.0, 6.0, 19.5, 20.37]
# Stack 5: [None, None, None, None, None]
# Stack 6: [6.6, 20.0, 24.0, None, None]
#
# Step 13: Placing new value 2.0 (actual weight: 2.0)
# Container index: 17, new_value: 2.0, loc_x: 5, loc_z: 0
# Placed new value 2.0 (actual weight: 2.0) in ideal position
# Stack 1: [2.96, 6.0, 42, 43, None]
# Stack 2: [3.5, None, None, None, None]
# Stack 3: [2.96, 3.5, 3.8, 17.4, None]
# Stack 4: [4.4, 5.0, 6.0, 19.5, 20.37]
# Stack 5: [2.0, None, None, None, None]
# Stack 6: [6.6, 20.0, 24.0, None, None]
#
# Step 14: Placing new value 3.0 (actual weight: 3.0)
# Container index: 18, new_value: 3.0, loc_x: 5, loc_z: 1
# Placed weight 3.0 in Stack 5, Tier 2
# Stack 1: [2.96, 6.0, 42, 43, None]
# Stack 2: [3.5, None, None, None, None]
# Stack 3: [2.96, 3.5, 3.8, 17.4, None]
# Stack 4: [4.4, 5.0, 6.0, 19.5, 20.37]
# Stack 5: [2.0, 3.0, None, None, None]
# Stack 6: [6.6, 20.0, 24.0, None, None]
#
# Step 15: Placing new value 4.0 (actual weight: 4.0)
# Container index: 19, new_value: 4.0, loc_x: 2, loc_z: 1
# Placed weight 4.0 in Stack 2, Tier 2
# Stack 1: [2.96, 6.0, 42, 43, None]
# Stack 2: [3.5, 4.0, None, None, None]
# Stack 3: [2.96, 3.5, 3.8, 17.4, None]
# Stack 4: [4.4, 5.0, 6.0, 19.5, 20.37]
# Stack 5: [2.0, 3.0, None, None, None]
# Stack 6: [6.6, 20.0, 24.0, None, None]
#
# Step 16: Placing new value 4.0 (actual weight: 4.0)
# Container index: 20, new_value: 4.0, loc_x: 2, loc_z: 2
# Placed weight 4.0 in Stack 2, Tier 3
# Stack 1: [2.96, 6.0, 42, 43, None]
# Stack 2: [3.5, 4.0, 4.0, None, None]
# Stack 3: [2.96, 3.5, 3.8, 17.4, None]
# Stack 4: [4.4, 5.0, 6.0, 19.5, 20.37]
# Stack 5: [2.0, 3.0, None, None, None]
# Stack 6: [6.6, 20.0, 24.0, None, None]
#
# Step 17: Placing new value 22.0 (actual weight: 22.0)
# Container index: 21, new_value: 22.0, loc_x: 3, loc_z: 4
# Placed weight 22.0 in Stack 3, Tier 5
# Stack 1: [2.96, 6.0, 42, 43, None]
# Stack 2: [3.5, 4.0, 4.0, None, None]
# Stack 3: [2.96, 3.5, 3.8, 17.4, 22.0]
# Stack 4: [4.4, 5.0, 6.0, 19.5, 20.37]
# Stack 5: [2.0, 3.0, None, None, None]
# Stack 6: [6.6, 20.0, 24.0, None, None]
#     idx  weight  new_value  relocation  loc_x  loc_y  loc_z  size(ft)
# 0     1    2.96       2.96           0      1      0      0        20
# 1     2    3.50       3.50           0      2      0      0        20
# 2     3   10.00      42.00           1      1      0      2        20
# 3     4   10.00      43.00           1      1      0      3        20
# 4   121    6.00       6.00           1      1      0      1        20
# 5   100    2.96       2.96           0      3      0      0        20
# 6     6    3.50       3.50           0      3      0      1        20
# 7     7    4.40       4.40           0      4      0      0        20
# 8     8    6.60       6.60           0      6      0      0        20
# 9     9    3.80       3.80           0      3      0      2        20
# 10   10    5.00       5.00           0      4      0      1        20
# 11   11    6.00       6.00           0      4      0      2        20
# 12   12   20.00      20.00           0      6      0      1        20
# 13   13   19.50      19.50           0      4      0      3        20
# 14   14   17.40      17.40           0      3      0      3        20
# 15   15   20.37      20.37           0      4      0      4        20
# 16   16   24.00      24.00           0      6      0      2        20
# 17   17    2.00       2.00           0      5      0      0        20
# 18   18    3.00       3.00           0      5      0      1        20
# 19   19    4.00       4.00           0      2      0      1        20
# 20   20    4.00       4.00           0      2      0      2        20
# 21   21   22.00      22.00           0      3      0      4        20
# Initial stacks before any new weights are added:
# Stack 1: [2.96, None, None, None, None]
# Stack 2: [3.5, None, None, None, None]
# Stack 3: [4.4, None, None, None, None]
# Stack 4: [42, None, None, None, None]
# Stack 5: [None, None, None, None, None]
# Stack 6: [None, None, None, None, None]
# -------------------------------------------------------------------
# Relocated weight 3.5 from Stack 2 to Stack 1
# Relocated weight 4.4 from Stack 3 to Stack 1
# Relocated weight 42 from Stack 4 to Stack 1
# Total relocations: 3
# Stacks after relocating initial stacks:
# Stack 1: [2.96, 3.5, 4.4, 42, None]
# Stack 2: [None, None, None, None, None]
# Stack 3: [None, None, None, None, None]
# Stack 4: [None, None, None, None, None]
# Stack 5: [None, None, None, None, None]
# Stack 6: [None, None, None, None, None]
# -------------------------------------------------------------------
# Empty stacks after relocation: [1, 2, 3, 4, 5]
# Ideal candidate location for new weights
# Level 1: [(1, 0), (1, 1), (2, 0), (1, 2), (2, 1), (3, 0), (1, 3), (2, 2)]
# Level 3: [(3, 1)]
# Level 4: [(4, 0), (1, 4), (2, 3)]
# Level 5: [(3, 2)]
# Level 8: [(4, 1)]
# Level 9: [(5, 0)]
# -------------------------------------------------------------------
# Weight 2.96: [(1, 0), (1, 1), (2, 0), (1, 2), (2, 1), (3, 0), (1, 3), (2, 2)]
# Weight 3.5: [(1, 0), (1, 1), (2, 0), (1, 2), (2, 1), (3, 0), (1, 3), (2, 2)]
# Weight 4.4: [(1, 0), (1, 1), (2, 0), (1, 2), (2, 1), (3, 0), (1, 3), (2, 2)]
# Weight 6.6: [(1, 0), (1, 1), (2, 0), (1, 2), (2, 1), (3, 0), (1, 3), (2, 2)]
# Weight 3.8: [(1, 0), (1, 1), (2, 0), (1, 2), (2, 1), (3, 0), (1, 3), (2, 2)]
# Weight 5.0: [(1, 0), (1, 1), (2, 0), (1, 2), (2, 1), (3, 0), (1, 3), (2, 2)]
# Weight 6.0: [(1, 0), (1, 1), (2, 0), (1, 2), (2, 1), (3, 0), (1, 3), (2, 2)]
# Weight 20.0: [(4, 0), (1, 4), (2, 3)]
# Weight 19.5: [(4, 0), (1, 4), (2, 3)]
# Weight 17.4: [(3, 1)]
# Weight 20.37: [(4, 0), (1, 4), (2, 3)]
# Weight 24.0: [(3, 2)]
# Weight 2.0: [(1, 0), (1, 1), (2, 0), (1, 2), (2, 1), (3, 0), (1, 3), (2, 2)]
# Weight 43: [(4, 1)]
# Weight 44: [(5, 0)]
# -------------------------------------------------------------------
#
# Step 1: Placing new value 2.96 (actual weight: 2.96)
# Container index: 5, new_value: 2.96, loc_x: 2, loc_z: 0
# Placed new value 2.96 (actual weight: 2.96) in ideal position
# Stack 1: [2.96, 3.5, 4.4, 42, None]
# Stack 2: [2.96, None, None, None, None]
# Stack 3: [None, None, None, None, None]
# Stack 4: [None, None, None, None, None]
# Stack 5: [None, None, None, None, None]
# Stack 6: [None, None, None, None, None]
#
# Step 2: Placing new value 3.5 (actual weight: 3.5)
# Container index: 6, new_value: 3.5, loc_x: 2, loc_z: 1
# Placed new value 3.5 (actual weight: 3.5) in ideal position
# Stack 1: [2.96, 3.5, 4.4, 42, None]
# Stack 2: [2.96, 3.5, None, None, None]
# Stack 3: [None, None, None, None, None]
# Stack 4: [None, None, None, None, None]
# Stack 5: [None, None, None, None, None]
# Stack 6: [None, None, None, None, None]
#
# Step 3: Placing new value 4.4 (actual weight: 4.4)
# Container index: 7, new_value: 4.4, loc_x: 3, loc_z: 0
# Placed new value 4.4 (actual weight: 4.4) in ideal position
# Stack 1: [2.96, 3.5, 4.4, 42, None]
# Stack 2: [2.96, 3.5, None, None, None]
# Stack 3: [4.4, None, None, None, None]
# Stack 4: [None, None, None, None, None]
# Stack 5: [None, None, None, None, None]
# Stack 6: [None, None, None, None, None]
#
# Step 4: Placing new value 6.6 (actual weight: 6.6)
# Container index: 8, new_value: 6.6, loc_x: 2, loc_z: 2
# Placed new value 6.6 (actual weight: 6.6) in ideal position
# Stack 1: [2.96, 3.5, 4.4, 42, None]
# Stack 2: [2.96, 3.5, 6.6, None, None]
# Stack 3: [4.4, None, None, None, None]
# Stack 4: [None, None, None, None, None]
# Stack 5: [None, None, None, None, None]
# Stack 6: [None, None, None, None, None]
#
# Step 5: Placing new value 3.8 (actual weight: 3.8)
# Container index: 9, new_value: 3.8, loc_x: 3, loc_z: 1
# Placed new value 3.8 (actual weight: 3.8) in ideal position
# Stack 1: [2.96, 3.5, 4.4, 42, None]
# Stack 2: [2.96, 3.5, 6.6, None, None]
# Stack 3: [4.4, 3.8, None, None, None]
# Stack 4: [None, None, None, None, None]
# Stack 5: [None, None, None, None, None]
# Stack 6: [None, None, None, None, None]
#
# Step 6: Placing new value 5.0 (actual weight: 5.0)
# Container index: 10, new_value: 5.0, loc_x: 4, loc_z: 0
# Placed new value 5.0 (actual weight: 5.0) in ideal position
# Stack 1: [2.96, 3.5, 4.4, 42, None]
# Stack 2: [2.96, 3.5, 6.6, None, None]
# Stack 3: [4.4, 3.8, None, None, None]
# Stack 4: [5.0, None, None, None, None]
# Stack 5: [None, None, None, None, None]
# Stack 6: [None, None, None, None, None]
#
# Step 7: Placing new value 6.0 (actual weight: 6.0)
# Container index: 11, new_value: 6.0, loc_x: 2, loc_z: 3
# Placed new value 6.0 (actual weight: 6.0) in ideal position
# Stack 1: [2.96, 3.5, 4.4, 42, None]
# Stack 2: [2.96, 3.5, 6.6, 6.0, None]
# Stack 3: [4.4, 3.8, None, None, None]
# Stack 4: [5.0, None, None, None, None]
# Stack 5: [None, None, None, None, None]
# Stack 6: [None, None, None, None, None]
#
# Step 8: Placing new value 20.0 (actual weight: 20.0)
# Container index: 12, new_value: 20.0, loc_x: 5, loc_z: 0
# Placed new value 20.0 (actual weight: 20.0) in ideal position
# Stack 1: [2.96, 3.5, 4.4, 42, None]
# Stack 2: [2.96, 3.5, 6.6, 6.0, None]
# Stack 3: [4.4, 3.8, None, None, None]
# Stack 4: [5.0, None, None, None, None]
# Stack 5: [20.0, None, None, None, None]
# Stack 6: [None, None, None, None, None]
#
# Step 9: Placing new value 19.5 (actual weight: 19.5)
# Container index: 13, new_value: 19.5, loc_x: 2, loc_z: 4
# Placed new value 19.5 (actual weight: 19.5) in ideal position
# Stack 1: [2.96, 3.5, 4.4, 42, None]
# Stack 2: [2.96, 3.5, 6.6, 6.0, 19.5]
# Stack 3: [4.4, 3.8, None, None, None]
# Stack 4: [5.0, None, None, None, None]
# Stack 5: [20.0, None, None, None, None]
# Stack 6: [None, None, None, None, None]
#
# Step 10: Placing new value 17.4 (actual weight: 17.4)
# Container index: 14, new_value: 17.4, loc_x: 4, loc_z: 1
# Placed new value 17.4 (actual weight: 17.4) in ideal position
# Stack 1: [2.96, 3.5, 4.4, 42, None]
# Stack 2: [2.96, 3.5, 6.6, 6.0, 19.5]
# Stack 3: [4.4, 3.8, None, None, None]
# Stack 4: [5.0, 17.4, None, None, None]
# Stack 5: [20.0, None, None, None, None]
# Stack 6: [None, None, None, None, None]
#
# Step 11: Placing new value 20.37 (actual weight: 20.37)
# Container index: 15, new_value: 20.37, loc_x: 5, loc_z: 1
# Placed weight 20.37 in Stack 5, Tier 2
# Stack 1: [2.96, 3.5, 4.4, 42, None]
# Stack 2: [2.96, 3.5, 6.6, 6.0, 19.5]
# Stack 3: [4.4, 3.8, None, None, None]
# Stack 4: [5.0, 17.4, None, None, None]
# Stack 5: [20.0, 20.37, None, None, None]
# Stack 6: [None, None, None, None, None]
#
# Step 12: Placing new value 24.0 (actual weight: 24.0)
# Container index: 16, new_value: 24.0, loc_x: 4, loc_z: 2
# Placed new value 24.0 (actual weight: 24.0) in ideal position
# Stack 1: [2.96, 3.5, 4.4, 42, None]
# Stack 2: [2.96, 3.5, 6.6, 6.0, 19.5]
# Stack 3: [4.4, 3.8, None, None, None]
# Stack 4: [5.0, 17.4, 24.0, None, None]
# Stack 5: [20.0, 20.37, None, None, None]
# Stack 6: [None, None, None, None, None]
#
# Step 13: Placing new value 2.0 (actual weight: 2.0)
# Container index: 17, new_value: 2.0, loc_x: 3, loc_z: 2
# Placed new value 2.0 (actual weight: 2.0) in ideal position
# Stack 1: [2.96, 3.5, 4.4, 42, None]
# Stack 2: [2.96, 3.5, 6.6, 6.0, 19.5]
# Stack 3: [4.4, 3.8, 2.0, None, None]
# Stack 4: [5.0, 17.4, 24.0, None, None]
# Stack 5: [20.0, 20.37, None, None, None]
# Stack 6: [None, None, None, None, None]
#
# Step 14: Placing new value 43 (actual weight: 3.0)
# Container index: 18, new_value: 43, loc_x: 1, loc_z: 4
# Placed weight 43 in Stack 1, Tier 5
# Stack 1: [2.96, 3.5, 4.4, 42, 43]
# Stack 2: [2.96, 3.5, 6.6, 6.0, 19.5]
# Stack 3: [4.4, 3.8, 2.0, None, None]
# Stack 4: [5.0, 17.4, 24.0, None, None]
# Stack 5: [20.0, 20.37, None, None, None]
# Stack 6: [None, None, None, None, None]
#
# Step 15: Placing new value 44 (actual weight: 4.0)
# Container index: 19, new_value: 44, loc_x: 6, loc_z: 0
# Placed new value 44 (actual weight: 4.0) in ideal position
# Stack 1: [2.96, 3.5, 4.4, 42, 43]
# Stack 2: [2.96, 3.5, 6.6, 6.0, 19.5]
# Stack 3: [4.4, 3.8, 2.0, None, None]
# Stack 4: [5.0, 17.4, 24.0, None, None]
# Stack 5: [20.0, 20.37, None, None, None]
# Stack 6: [44, None, None, None, None]
#     idx  weight  new_value  relocation  loc_x  loc_y  loc_z  size(ft)
# 0     1    2.96       2.96           0      1      0      0        20
# 1     2    3.50       3.50           1      1      0      1        20
# 2     3    4.40       4.40           1      1      0      2        20
# 3     4   10.00      42.00           1      1      0      3        20
# 4     5    2.96       2.96           0      2      0      0        20
# 5     6    3.50       3.50           0      2      0      1        20
# 6     7    4.40       4.40           0      3      0      0        20
# 7     8    6.60       6.60           0      2      0      2        20
# 8     9    3.80       3.80           0      3      0      1        20
# 9    10    5.00       5.00           0      4      0      0        20
# 10   11    6.00       6.00           0      2      0      3        20
# 11   12   20.00      20.00           0      5      0      0        20
# 12   13   19.50      19.50           0      2      0      4        20
# 13   14   17.40      17.40           0      4      0      1        20
# 14   15   20.37      20.37           0      5      0      1        20
# 15   16   24.00      24.00           0      4      0      2        20
# 16   17    2.00       2.00           0      3      0      2        20
# 17   18    3.00      43.00           0      1      0      4        20
# 18   19    4.00      44.00           0      6      0      0        20
